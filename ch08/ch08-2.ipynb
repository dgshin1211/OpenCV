# %%
# !pip install opencv-python

import cv2
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# img = cv2.imread('/content/gdrive/My Drive/Colabip/Images/fce(salt_pepper noise).bmp')
img = cv2.imread('/content/gdrive/My Drive/Colabip/Images/text.1.png')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg= cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imshow(gimg,cmap='gray')
# Out:
# (158, 462)

# %%
kernel = np.ones((3, 3),np.uint8)
dilateimg = cv2.dilate(gimg,kernel,iterations = 1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=462x158>

# %%
kernel = np.ones((3, 1),np.uint8)
dilateimg = cv2.dilate(gimg,kernel,iterations = 2)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=462x158>

# %%
kernel = np.ones((3, 3),np.uint8)
erodeimg = cv2.erode(gimg,kernel,iterations = 1)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=462x158>

# %%
img = cv2.imread('/content/gdrive/My Drive/Colabip/Images/fce(salt_pepper noise).bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg= cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imshow(gimg,cmap='gray')
# Out:
# (256, 256)

# %%
kernel = np.ones((3, 3),np.uint8)
dilateimg = cv2.dilate(gimg,kernel,iterations = 1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((4, 1),np.uint8)
erodeimg = cv2.erode(dilateimg,kernel,iterations = 6)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
